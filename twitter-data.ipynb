# %%
pip install twitterscraper
# Out:
# Requirement already satisfied: twitterscraper in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (1.4.0)
# Requirement already satisfied: coala-utils~=0.5.0 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from twitterscraper) (0.5.1)
# Requirement already satisfied: bs4 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from twitterscraper) (0.0.1)
# Requirement already satisfied: lxml in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from twitterscraper) (4.5.0)
# Requirement already satisfied: requests in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from twitterscraper) (2.23.0)
# Requirement already satisfied: billiard in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from twitterscraper) (3.6.1.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from bs4->twitterscraper) (4.8.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from requests->twitterscraper) (2019.11.28)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from requests->twitterscraper) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from requests->twitterscraper) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from requests->twitterscraper) (1.25.9)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\dell\appdata\local\programs\python\python37\lib\site-packages (from beautifulsoup4->bs4->twitterscraper) (1.9.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Scrapping
import pandas as pd
import datetime as dt 
from twitterscraper import query_tweets
import matplotlib.pyplot as plt
import numpy as np
from wordcloud import WordCloud, STOPWORDS
import re



# taking necessary input like date range , topic string to search 
start_y=int(input())
start_m=int(input())
start_d=int(input())
end_y=int(input())
end_m=int(input())
end_d=int(input())
search_topic=input()
# default language is english
lang= 'english'

#assigning dates , querying the tweets using the imported packeges

begin_date=dt.date(start_y,start_m,start_d)
end_date=dt.date(end_y,end_m,end_d)
limit=10000
tweet_data=query_tweets(search_topic,begindate=begin_date , enddate=end_date, limit=limit ,lang=lang)

# creating a csv file of collected tweets data
df=pd.DataFrame(obj.__dict__ for obj in tweet_data)
#df.drop(['timestamp_epochs','html'],axis=1)
df.to_csv('coronavirusdata.csv')

comment_words=' '
stopwords = set(STOPWORDS) 
for val in df['text']:
    t=set()
    val = re.sub('https[A-Za-z0-9.]+','',val) 
    tokens = val.split()  
    for word in tokens:
      t.add(word.lower())
    t=list(t)  
    for words in t: 
        comment_words = comment_words + words + ' '
   
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words) 
                          
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
#plt.axis(off) 
plt.tight_layout(pad = 0) 
plt.show()
# Out:
# 2019
# 11
# 1
# 2020
# 5
# 30
# coronavirus
# INFO: queries: ['coronavirus since:2019-11-01 until:2019-11-11', 'coronavirus since:2019-11-11 until:2019-11-22', 'coronavirus since:2019-11-22 until:2019-12-02', 'coronavirus since:2019-12-02 until:2019-12-13', 'coronavirus since:2019-12-13 until:2019-12-23', 'coronavirus since:2019-12-23 until:2020-01-03', 'coronavirus since:2020-01-03 until:2020-01-13', 'coronavirus since:2020-01-13 until:2020-01-24', 'coronavirus since:2020-01-24 until:2020-02-03', 'coronavirus since:2020-02-03 until:2020-02-14', 'coronavirus since:2020-02-14 until:2020-02-25', 'coronavirus since:2020-02-25 until:2020-03-06', 'coronavirus since:2020-03-06 until:2020-03-17', 'coronavirus since:2020-03-17 until:2020-03-27', 'coronavirus since:2020-03-27 until:2020-04-07', 'coronavirus since:2020-04-07 until:2020-04-17', 'coronavirus since:2020-04-17 until:2020-04-28', 'coronavirus since:2020-04-28 until:2020-05-08', 'coronavirus since:2020-05-08 until:2020-05-19', 'coronavirus since:2020-05-19 until:2020-05-30']
# INFO: Got 503 tweets (503 new).
# INFO: Got 1019 tweets (516 new).
# INFO: Got 1524 tweets (505 new).
# INFO: Got 2035 tweets (511 new).
# INFO: Got 2554 tweets (519 new).
# INFO: Got 3070 tweets (516 new).
# INFO: Got 3582 tweets (512 new).
# INFO: Got 4099 tweets (517 new).
# INFO: Got 4601 tweets (502 new).
# INFO: Got 5111 tweets (510 new).
# INFO: Got 5613 tweets (502 new).
# INFO: Got 6130 tweets (517 new).
# INFO: Got 6638 tweets (508 new).
# INFO: Got 7151 tweets (513 new).
# INFO: Got 7657 tweets (506 new).
# INFO: Got 8172 tweets (515 new).
# INFO: Got 8680 tweets (508 new).
# INFO: Got 9187 tweets (507 new).
# INFO: Got 9706 tweets (519 new).
# INFO: Got 10212 tweets (506 new).

# %%
#Scrapping
import pandas as pd
import datetime as dt 
from twitterscraper import query_tweets
import matplotlib.pyplot as plt
import numpy as np
from wordcloud import WordCloud, STOPWORDS
import re



# taking necessary input like date range , topic string to search 
start_y=int(input())
start_m=int(input())
start_d=int(input())
end_y=int(input())
end_m=int(input())
end_d=int(input())
search_topic=input()
# default language is english
lang= 'english'

#assigning dates , querying the tweets using the imported packeges

begin_date=dt.date(start_y,start_m,start_d)
end_date=dt.date(end_y,end_m,end_d)
limit=10000
tweet_data=query_tweets(search_topic,begindate=begin_date , enddate=end_date, limit=limit ,lang=lang)

# creating a csv file of collected tweets data
df=pd.DataFrame(obj.__dict__ for obj in tweet_data)
#df.drop(['timestamp_epochs','html'],axis=1)
df.to_csv('coronavirusinindia.csv')

comment_words=' '
stopwords = set(STOPWORDS) 
for val in df['text']:
    t=set()
    val = re.sub('https[A-Za-z0-9.]+','',val) 
    tokens = val.split()  
    for word in tokens:
      t.add(word.lower())
    t=list(t)  
    for words in t: 
        comment_words = comment_words + words + ' '
   
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words) 
                          
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
#plt.axis(off) 
plt.tight_layout(pad = 0) 
plt.show()
# Out:
# 2019
# 11
# 1
# 2020
# 5
# 30
# coronavirusinindia
# INFO: queries: ['coronavirusinindia since:2019-11-01 until:2019-11-11', 'coronavirusinindia since:2019-11-11 until:2019-11-22', 'coronavirusinindia since:2019-11-22 until:2019-12-02', 'coronavirusinindia since:2019-12-02 until:2019-12-13', 'coronavirusinindia since:2019-12-13 until:2019-12-23', 'coronavirusinindia since:2019-12-23 until:2020-01-03', 'coronavirusinindia since:2020-01-03 until:2020-01-13', 'coronavirusinindia since:2020-01-13 until:2020-01-24', 'coronavirusinindia since:2020-01-24 until:2020-02-03', 'coronavirusinindia since:2020-02-03 until:2020-02-14', 'coronavirusinindia since:2020-02-14 until:2020-02-25', 'coronavirusinindia since:2020-02-25 until:2020-03-06', 'coronavirusinindia since:2020-03-06 until:2020-03-17', 'coronavirusinindia since:2020-03-17 until:2020-03-27', 'coronavirusinindia since:2020-03-27 until:2020-04-07', 'coronavirusinindia since:2020-04-07 until:2020-04-17', 'coronavirusinindia since:2020-04-17 until:2020-04-28', 'coronavirusinindia since:2020-04-28 until:2020-05-08', 'coronavirusinindia since:2020-05-08 until:2020-05-19', 'coronavirusinindia since:2020-05-19 until:2020-05-30']
# INFO: Got 6 tweets (6 new).
# INFO: Got 72 tweets (66 new).
# INFO: Got 189 tweets (117 new).
# INFO: Got 695 tweets (506 new).
# INFO: Got 1196 tweets (501 new).
# INFO: Got 1699 tweets (503 new).
# INFO: Got 2212 tweets (513 new).
# INFO: Got 2725 tweets (513 new).
# INFO: Got 3238 tweets (513 new).
# INFO: Got 3743 tweets (505 new).
# INFO: Got 4257 tweets (514 new).
# INFO: Got 4769 tweets (512 new).
# INFO: Got 4769 tweets (0 new).
# INFO: Got 4769 tweets (0 new).
# INFO: Got 4769 tweets (0 new).
# INFO: Got 4769 tweets (0 new).
# INFO: Got 4769 tweets (0 new).
# INFO: Got 4769 tweets (0 new).
# INFO: Got 4769 tweets (0 new).
# INFO: Got 4769 tweets (0 new).
